# %%
from IPython.display import Image, clear_output
# !pip install roboflow
# !pip install ultralytics
clear_output()

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="pJ6f3Rp4Fy4g43yEHmF1")
project = rf.workspace("ryan-kraus").project("traffic-cam")
dataset = project.version(3).download("yolov8", location='drive/Shared drives/Spring 2023/Machine Learning Capstone/')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.87, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to drive/Shared drives/Spring 2023/Machine Learning Capstone/ in yolov8:: 100%|██████████| 11922/11922 [12:42<00:00, 15.63it/s]

# %%
dataset.location
# Out:
# '/content/drive/Shared drives/Spring 2023/Machine Learning Capstone'

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
model.train(data='/content/drive/Shared drives/Spring 2023/Machine Learning Capstone/data.yaml', epochs=10, task='detect', optimizer='Adam')
metrics = model.val()

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !pip install ultralyticsplus
clear_output()

# %%
from ultralyticsplus import YOLO, render_result

results = model.predict(source="drive/Shared drives/Spring 2023/Machine Learning Capstone/test/images/Aptakisic-at-Brandywyn-East-2_jpg.rf.dc24529d185ab387b09ecaf26001160a.jpg", conf=0.25, show_conf=False, show_labels=False)
#print(results[0].boxes)
render = render_result(model=model, image="drive/Shared drives/Spring 2023/Machine Learning Capstone/test/images/Aptakisic-at-Brandywyn-East-2_jpg.rf.dc24529d185ab387b09ecaf26001160a.jpg", result=results[0])
render.show()
# Out:
# image 1/1 /content/drive/Shared drives/Spring 2023/Machine Learning Capstone/test/images/Aptakisic-at-Brandywyn-East-2_jpg.rf.dc24529d185ab387b09ecaf26001160a.jpg: 640x640 7 cars, 11.2ms
# Speed: 0.7ms preprocess, 11.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7F0066831640>

# %%
Image(filename="drive/Shared drives/Spring 2023/Machine Learning Capstone/test/images/Aptakisic-at-Brandywyn-East-2_jpg.rf.dc24529d185ab387b09ecaf26001160a.jpg", height=600)

# %%
results2 = model.predict(source="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t1.png", conf=0.25)
#print(results[0].boxes)
render2 = render_result(model=model, image="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t1.png", result=results2[0])
render2.show()
# Out:
# image 1/1 /content/drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t1.png: 416x640 2 cars, 9.2ms
# Speed: 0.7ms preprocess, 9.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=410x265 at 0x7F00103B1490>

# %%
results3 = model.predict(source="drive/Shared drives/Spring 2023/Machine Learning Capstone/test/images/IL-21-at-Gages-Lake-South-6_jpg.rf.00bc54caa218a839a377e8b303d9fa60.jpg", conf=0.25)
#print(results[0].boxes)
render3 = render_result(model=model, image="drive/Shared drives/Spring 2023/Machine Learning Capstone/test/images/IL-21-at-Gages-Lake-South-6_jpg.rf.00bc54caa218a839a377e8b303d9fa60.jpg", result=results3[0])
render3.show()
# Out:
# image 1/1 /content/drive/Shared drives/Spring 2023/Machine Learning Capstone/test/images/IL-21-at-Gages-Lake-South-6_jpg.rf.00bc54caa218a839a377e8b303d9fa60.jpg: 640x640 15 cars, 10.1ms
# Speed: 0.8ms preprocess, 10.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=416x416 at 0x7F0066918850>

# %%
Image(filename="drive/Shared drives/Spring 2023/Machine Learning Capstone/test/images/IL-21-at-Gages-Lake-South-6_jpg.rf.00bc54caa218a839a377e8b303d9fa60.jpg", height=600)

# %%
results4 = model.predict(source="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t4.png", conf=0.25)
#print(results[0].boxes)
render4 = render_result(model=model, image="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t4.png", result=results4[0])
render4.show()
# Out:
# image 1/1 /content/drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t4.png: 416x640 11 cars, 7.7ms
# Speed: 0.7ms preprocess, 7.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=410x265 at 0x7F006AB8AA00>

# %%
Image(filename="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t4.png", height=600)

# %%
results5 = model.predict(source="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t5.png", conf=0.25)
#print(results[0].boxes)
render5 = render_result(model=model, image="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t5.png", result=results5[0])
render5.show()
# Out:
# image 1/1 /content/drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t5.png: 416x640 27 cars, 9.2ms
# Speed: 0.7ms preprocess, 9.2ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=410x265 at 0x7F006AC85610>

# %%
Image(filename="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t5.png", height=600)

# %%
results7 = model.predict(source="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t7.png", conf=0.25)
#print(results[0].boxes)
render7 = render_result(model=model, image="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t7.png", result=results7[0])
render7.show()
# Out:
# image 1/1 /content/drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t7.png: 416x640 27 cars, 8.5ms
# Speed: 0.6ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=410x265 at 0x7F006AC189D0>

# %%
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.87 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# PyTorch: starting from runs/detect/train2/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.13.1 opset 17...
# ONNX: export success ✅ 2.6s, saved as runs/detect/train2/weights/best.onnx (11.7 MB)
#
# Export complete (3.7s)
# Results saved to /content/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=runs/detect/train2/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train2/weights/best.onnx imgsz=640 data=/content/drive/Shared drives/Spring 2023/Machine Learning Capstone/data.yaml
# Visualize:       https://netron.app
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# 'runs/detect/train2/weights/best.onnx'
