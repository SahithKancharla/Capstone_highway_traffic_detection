# %%
# Loading the drive helper and mounting
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
# !ls "drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try"
# Out:
# t1.png	t2.png

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# importing all the libraries
import numpy as np
import pandas as pd
import random
import os
import matplotlib.pyplot as plt
from matplotlib.image import imread
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
#path = "drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/train/dense_traffic"
#rand_img = imread(path+'/'+random.choice(sorted(os.listdir(path))))
results = model.predict(source="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t2.png", conf=0.25)
# Out:
# image 1/1 /content/drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t2.png: 416x640 6 cars, 103.2ms
# Speed: 0.7ms preprocess, 103.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
from IPython import display
from IPython.display import display, Image

Image(filename="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t2.png", height=600)

# %%
results2 = model.predict(source="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t1.png", conf=0.25)
# Out:
# image 1/1 /content/drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t1.png: 416x640 2 cars, 151.0ms
# Speed: 7.1ms preprocess, 151.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
Image(filename="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t1.png", height=600)

# %%
results2 = model.predict(source="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t3.png", conf=0.25)
# Out:
# image 1/1 /content/drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t3.png: 416x640 (no detections), 113.5ms
# Speed: 1.7ms preprocess, 113.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
Image(filename="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/try/t3.png", height=600)

# %%
results3 = model.predict(source="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/train/accident/images_213 (2).jpg", conf=0.25)
# Out:
# image 1/1 /content/drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/train/accident/images_213 (2).jpg: 480x640 4 persons, 1 bus, 1 train, 120.4ms
# Speed: 2.0ms preprocess, 120.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
Image(filename="drive/Shared drives/Spring 2023/Machine Learning Capstone/trafficnet_dataset_v1/train/accident/images_213 (2).jpg", height=600)
